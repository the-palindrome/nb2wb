# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# # From Jupyter Notebook to Web
#
# This notebook demonstrates the `nb2wb` converter. It covers the three pillars
# of technical writing: prose, mathematics, and code.
#
# Here's a nice image for illustration.

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: The parallelogram rule)

# %% [markdown]
# You can render bulleted lists, numbered lists, and tables as well.
#
# Here's a bulleted list:
#
# * Apples
# * Bananas
# * Oranges
#
# Here's a numbered list:
#
# 1. Wash the fruit
# 2. Peel the fruit
# 3. Eat the fruit
#
# And here's a table:

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted table content.
#
# Source image: `data:image/png;base64,...` (alt: table)

# %% [markdown]
# ## 1 Inline LaTeX → Unicode
#
# Inline expressions like *α* + *β* = *γ* or *f*(*x*) = sin(*x*²) − log(2*x*) are converted to Unicode so they render as plain readable text in Substack's editor.
#
# Other examples: the golden ratio *ϕ* = (1+√5)/(2), and Euler's identity *e*iπ + 1 = 0.
#
# ## 2 Display Math → Image
#
# Block equations are rendered to crisp PNG images.
#
# The quadratic formula:

# %% [markdown]
# ```latex
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} \label{eq:quadratic}
# ```

# %% [markdown]
# is rendered to

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# You can render the equation references as `\\eqref{eq:quadratic}`, which renders like this: (1) gives both roots of *a**x*² + *b**x* + *c* = 0 simultaneously.
#
# You can also use colors that are defined in the preamble. Bayes' theorem:

# %% [markdown]
# ```latex
# P({\color{maizeCrayola} A} \mid {\color{blueGray} B}) = \frac{P({\color{blueGray} B} \mid {\color{maizeCrayola} A})\, P({\color{maizeCrayola} A})}{P({\color{blueGray} B})} \label{eq:bayes}
# ```

# %% [markdown]
# is rendered to

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# A matrix equation:

# %% [markdown]
# ```latex
# \mathbf{y} = \mathbf{X}\boldsymbol{\beta} + \boldsymbol{\varepsilon} \label{eq:mtx}
# ```

# %% [markdown]
# is rendered to

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# The Basel formula:

# %% [markdown]
# ```latex
# \sum_{n=1}^{\infty} \frac{1}{n^2} = \frac{\pi^2}{6}
# ```

# %% [markdown]
# is rendered to

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# Now, a complex multi-line example. The Gaussian integral, derived by switching to polar coordinates:

# %% [markdown]
# ```latex
# \begin{align*}
# I   &= \int_{-\infty}^{\infty} e^{-x^2}\,dx \\[4pt]
# I^2 &= \int_{-\infty}^{\infty}\!\int_{-\infty}^{\infty} e^{-(x^2+y^2)}\,dx\,dy \\[4pt]
#     &= \int_0^{2\pi}\!\int_0^{\infty} e^{-r^2}\,r\,dr\,d\theta \\[4pt]
#     &= 2\pi \cdot \Bigl[-\tfrac{1}{2}e^{-r^2}\Bigr]_0^{\infty} \\[4pt]
#     &= \pi \\[4pt]
# \therefore\quad I &= \sqrt{\pi}
# \end{align*}
# ```

# %% [markdown]
# is rendered to

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# ## 3 Code Blocks → Image
#
# Code cells and their outputs are rendered as syntax-highlighted images,
# so formatting and colours are perfectly preserved.

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: code)

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: code)

# %% [markdown]
# ## 4 Mixed: equation in context
#
# The softmax function maps a vector 𝐳 ∈ ℝᴷ to a
# probability distribution:

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: math)

# %% [markdown]
# Here *j* = 1, …, *K* indexes the classes. Note that ∑ⱼ *σ*ⱼ = 1
# by construction.

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: code)

# %% [markdown]
# ## 5 Figures

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: code)

# %% [markdown]
# ## 6 Cell Tags
#
# Cells can be tagged to control what appears in the output.
# Tags are set via **Edit → Cell Metadata** (or the cell toolbar) in Jupyter.

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted table content.
#
# Source image: `data:image/png;base64,...` (alt: table)

# %% [markdown]
# The next cell is tagged `hide-input`: only its output is rendered.

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: code)

# %% [markdown]
# The next cell is tagged `hide-output`: only its source code is rendered.

# %% [markdown]
# TODO(wb2nb): Replace this placeholder with OCR-extracted LaTeX.
#
# Source image: `data:image/png;base64,...` (alt: code)

# %% [markdown]
# The next cell is tagged `text-snippet`: it is rendered as a HTML `<code>` snippet.

# %% [markdown]
# ```
# def square(x):
#     return x**2
# ```

# %% [markdown]
# The setup cell at the top of this notebook is tagged `hide-cell` and is invisible in the output.
#
# #content
